# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['axes.facecolor'] = 'white'
plt.style.use('ggplot')

# %%
df=pd.read_csv("ev-charging-stations-india.csv")

# %%
df.head()
# Out:
#                                                 name          state      city  \
# 0                 Neelkanth Star DC Charging Station        Haryana  Gurugram
# 1                       Galleria DC Charging Station        Haryana  Gurugram
# 2  Highway Xpress (Jaipur-Delhi) DC charging station      Rajasthan    Behror
# 3                  Food Carnival DC Charging Station  Uttar Pradesh  Khatauli
# 4                  Food Carnival AC Charging Station  Uttar Pradesh  Khatauli
#
#                                              address lattitude  longitude  \
# 0  Neelkanth Star Karnal, NH 44, Gharunda, Kutail...   29.6019    76.9803
# 1  DLF Phase IV, Sector 28, Gurugram, Haryana 122022   28.4673    77.0818
# 2  Jaipur to Delhi Road, Behror Midway, Behror, R...   27.8751    76.2760
# 3  Fun and Food Carnival, NH 58, Khatauli Bypass,...   29.3105    77.7218
# 4  NH 58, Khatauli Bypass, Bhainsi, Uttar Pradesh...   29.3105    77.7218
#
#    type
# 0  12.0
# 1  12.0
# 2  12.0
# 3  12.0
# ...

# %%
print(df.columns)
# Out:
# Index(['name', 'state', 'city', 'address', 'lattitude', 'longitude', 'type'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    name          state  \
# 0                    Neelkanth Star DC Charging Station        Haryana
# 1                          Galleria DC Charging Station        Haryana
# 2     Highway Xpress (Jaipur-Delhi) DC charging station      Rajasthan
# 3                     Food Carnival DC Charging Station  Uttar Pradesh
# 4                     Food Carnival AC Charging Station  Uttar Pradesh
# ...                                                 ...            ...
# 1542                                        Tata Power          Kerala
# 1543                                        Tata Power         Haryana
# 1544                                        Tata Power         Haryana
# 1545                                        Tata Power           Jammu
# 1546                                        Tata Power       Karnataka
#
#            city                                            address  \
# ...

# %%
lst2= df.columns
for i in lst2:
    print(i, df[i].isna().sum() )
# Out:
# name 0
# state 0
# city 0
# address 40
# lattitude 6
# longitude 6
# type 8

# %%
df.drop('address',inplace=True,axis=1)

# %%
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.histplot(df['state'])
plt.title("Histogram Plot for Age")
plt.subplot(1,2,2)
sns.histplot(df["city"])
#plt.xticks(rotation=75)
# Out:
# <AxesSubplot:xlabel='city', ylabel='Count'>

# %%
plt.rcParams["figure.figsize"]=(20,8)
cntplt=sns.countplot(df["state"])
plt.title("Age Distribution of Customers")
plt.xlabel("States")
plt.xticks(rotation=75)
plt.ylabel("Count of Chaging Stations")
# Out:
# Text(0, 0.5, 'Count of Chaging Stations')

# %%
#19.7515° N, 75.7139° E
#df.hist(figsize=(22,12))

# %%
df_maha=df.loc[df['state'] == 'Maharashtra']

# %%
df_maha.head()
# Out:
#                                        name        state     city lattitude  \
# 12  Synergy Solutions AC Charging Station 2  Maharashtra     Pune    18.538
# 19                 Kothari Enterprises  AC1  Maharashtra  Khopoli   18.7876
# 22   Lonavla Wax Museum DC Charging Station  Maharashtra  Lonavla    18.763
# 32         Tellus Power DC Charging Station  Maharashtra     Pune   17.0749
# 34  Synergy Solutions AC Charging Station 1  Maharashtra     Pune   18.5145
#
#     longitude  type
# 12    73.8485  12.0
# 19    73.3475  12.0
# 22    73.4252  12.0
# 32    74.2227  12.0
# 34    73.8489  12.0

# %%
df_maha['type'].unique()
# Out:
# array([12.,  6.,  7., 13.,  8., 18., nan, 21., 24.])

# %%
plt.rcParams["figure.figsize"]=(20,8)
cntplt=sns.countplot(df_maha["city"])
plt.title("Age Distribution of Customers")
plt.xlabel("States")
plt.xticks(rotation=75)
plt.ylabel("Count of Chaging Stations")
# Out:
# Text(0, 0.5, 'Count of Chaging Stations')

# %%
print(df_maha['city'].value_counts())
print("<-------------------------------------------------------------------->")
print(df['state'].value_counts())
# Out:
# Mumbai       41
# Pune         34
# Nashik       15
# bengaluru    12
# mumbai        7
#              ..
# Belgavi       1
# Lonavala      1
# Mumbai        1
# Mahad         1
# Amravati      1
# Name: city, Length: 86, dtype: int64
# <-------------------------------------------------------------------->
# Maharashtra          259
# Tamil Nadu           155
# Karnataka            134
# Delhi                126
# Kerala                91
# Uttar Pradesh         87
# Gujarat               77
# Telangana             75
# Rajasthan             68
# Haryana               60
# Delhi NCR             53
# West Bengal           53
# Odisha                38
# Andhra Pradesh        31
# Andhra pradesh        24
# Jharkhand             22
# Uttarakhand           21
# Madhya Pradesh        20
# TAMIL NADU            20
# Punjab                15
# Chhattisgarh          12
# Assam                 10
# PUNJAB                 9
# Bihar                  9
# Goa                    8
# ...

# %%
#df_counts=pd.Series(df_maha['city'].value_counts()>=10)

# %%
#sns.lineplot(x=df['state'])

# %%
city=df_maha['city'].value_counts()
for i in city.index:
    if city[i]<10:
        city.drop(i,inplace=True)
#city=city.to_frame()
#city['c1']=city.index
#city.index=range(0,4)
#city
sns.barplot(city.index,city)
# Out:
# <AxesSubplot:ylabel='city'>

# %%
state=df['state'].value_counts()
for i in state.index:
    if state[i]<50:
        state.drop(i,inplace=True)
sns.barplot(state.index,state)
# Out:
# <AxesSubplot:ylabel='state'>
